# %% [markdown]
# <a href="https://colab.research.google.com/github/angiecombs11-ops/PurdueHW/blob/main/Capstone1_11_9_25.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
csv_path = 'NSMES1988.csv'

# %% [markdown]
# # Analysis Summary
#
# ## Data Export
#
# * The DataFrame `df` has been successfully exported to a JSON file named `NSMES1988.json`.
# * The data is formatted with each record on a new line.
# * You can now download the `NSMES1988.json` file from the Colab environment using the provided code.
#
# ## Categorical Column Distributions
#
# * The following columns were identified as categorical: 'health', 'adl', 'region', 'gender', 'married', 'employed', 'insurance', and 'medicaid'.
# * Visualizations (count plots) were generated for each of these columns, showing the distribution of unique values.
#
# ## Negative Income Values
#
# * There are 3 rows in the dataset with negative income values.
# * The range of negative income values is between -1.0125 and -0.818.
# * These values warrant further investigation to understand their source and determine the appropriate handling strategy.
#
# ## Next Steps
#
# * Review the generated plots for categorical distributions to understand value imbalances.
# * Investigate the negative income values further.
# * Continue exploring the data based on your analysis goals.

# %%
from google.colab import files
files.download('NSMES1988.json')

# %%
df.to_json('NSMES1988.json', orient='records', lines=True)

# %% [markdown]
# ## Summary:
#
# ### Data Export
#
# * The DataFrame `df` has been successfully exported to a JSON file named `NSMES1988.json`.
# * The data is formatted with each record on a new line.
#
# ### Next Steps
#
# * You can now download the `NSMES1988.json` file from the Colab environment.
# * You can use this JSON file for further analysis or in other applications.

# %%
categorical_cols = df.select_dtypes(include='object').columns

for col in categorical_cols:
    print(f"Unique values in '{col}':")
    display(df[col].unique())
# Out:
# Unique values in 'health':
# array(['average', 'poor', 'excellent'], dtype=object)
# Unique values in 'adl':
# array(['normal', 'limited'], dtype=object)
# Unique values in 'region':
# array(['other', 'midwest', 'northeast', 'west'], dtype=object)
# Unique values in 'gender':
# array(['male', 'female'], dtype=object)
# Unique values in 'married':
# array(['yes', 'no'], dtype=object)
# Unique values in 'employed':
# array(['yes', 'no'], dtype=object)
# Unique values in 'insurance':
# array(['yes', 'no'], dtype=object)
# Unique values in 'medicaid':
# array(['no', 'yes'], dtype=object)

# %%
correlation_matrix = df.corr(numeric_only=True)
display(correlation_matrix)
# Out:
#             Unnamed: 0    visits   nvisits   ovisits  novisits  emergency  \
# Unnamed: 0    1.000000 -0.021873  0.009741 -0.000072  0.015489  -0.002922
# visits       -0.021873  1.000000  0.226365  0.068144  0.078468   0.158748
# nvisits       0.009741  0.226365  1.000000  0.001129  0.041768   0.049056
# ovisits      -0.000072  0.068144  0.001129  1.000000  0.466923   0.065388
# novisits      0.015489  0.078468  0.041768  0.466923  1.000000   0.024083
# emergency    -0.002922  0.158748  0.049056  0.065388  0.024083   1.000000
# hospital      0.012327  0.240789  0.050401  0.110573  0.065301   0.476061
# chronic       0.002928  0.261886  0.037113  0.100805  0.040748   0.203845
# age          -0.014648  0.003404 -0.041640 -0.040028 -0.032813   0.061023
# school       -0.033246  0.064433  0.085974 -0.012156 -0.011733  -0.071192
# income        0.001205 -0.004951  0.010731 -0.004267 -0.007786  -0.026462
#
#             hospital   chronic       age    school    income
# ...

# %%
display(df.isnull().sum())
# Out:
# Unnamed: 0    0
# visits        0
# nvisits       0
# ovisits       0
# novisits      0
# emergency     0
# hospital      0
# health        0
# chronic       0
# adl           0
# region        0
# age           0
# gender        0
# married       0
# school        0
# income        0
# employed      0
# insurance     0
# medicaid      0
# dtype: int64

# %% [markdown]
# ## Visual Observations Report
#
# Based on the visualizations and data exploration performed:
#
# *   **Categorical Distributions:** The count plots for the categorical columns (`health`, `adl`, `region`, `gender`, `married`, `employed`, `insurance`, and `medicaid`) show the distribution of unique values in each category. For example, we can see the counts of individuals in different health categories, regions, or marital statuses. These plots help identify if there are any significant imbalances in the distribution of categories.
#
# *   **Numerical Data:** While we haven't generated specific plots for numerical columns yet (other than implicitly through `df.describe()` and the correlation matrix), the descriptive statistics provide insights into their distributions. For instance, we observed the range and spread of values for columns like `visits`, `age`, and `income`. The presence of negative values in the `income` column was also noted during the data exploration.
#
# *   **Correlations:** The correlation matrix provided numerical values indicating the relationships between numerical columns. While not a direct visualization in the form of a plot, the matrix itself allows for a visual scan to identify strong positive or negative correlations between variables.
#
# To gain a more comprehensive understanding of the data's visual aspects, generating plots for numerical distributions (histograms, box plots) and a heatmap for the correlation matrix would be beneficial.

# %%
df.to_csv('NSMES1988new.csv', index=False)

# %%
display(df.describe())
# Out:
#         Unnamed: 0       visits      nvisits      ovisits     novisits  \
# count  4406.000000  4406.000000  4406.000000  4406.000000  4406.000000
# mean   2203.500000     5.774399     1.618021     0.750794     0.536087
# std    1272.046972     6.759225     5.317056     3.652759     3.879506
# min       1.000000     0.000000     0.000000     0.000000     0.000000
# 25%    1102.250000     1.000000     0.000000     0.000000     0.000000
# 50%    2203.500000     4.000000     0.000000     0.000000     0.000000
# 75%    3304.750000     8.000000     1.000000     0.000000     0.000000
# max    4406.000000    89.000000   104.000000   141.000000   155.000000
#
#          emergency     hospital      chronic          age       school  \
# count  4406.000000  4406.000000  4406.000000  4406.000000  4406.000000
# mean      0.263504     0.295960     1.541988     7.402406    10.290286
# std       0.703659     0.746398     1.349632     0.633405     3.738736
# ...

# %%
display(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4406 entries, 0 to 4405
# Data columns (total 19 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  4406 non-null   int64
#  1   visits      4406 non-null   int64
#  2   nvisits     4406 non-null   int64
#  3   ovisits     4406 non-null   int64
#  4   novisits    4406 non-null   int64
#  5   emergency   4406 non-null   int64
#  6   hospital    4406 non-null   int64
#  7   health      4406 non-null   object
#  8   chronic     4406 non-null   int64
#  9   adl         4406 non-null   object
#  10  region      4406 non-null   object
#  11  age         4406 non-null   float64
#  12  gender      4406 non-null   object
#  13  married     4406 non-null   object
#  14  school      4406 non-null   int64
#  15  income      4406 non-null   float64
#  16  employed    4406 non-null   object
#  17  insurance   4406 non-null   object
#  18  medicaid    4406 non-null   object
# ...

# %%
df = pd.read_csv(csv_path)
display(df.head())
# Out:
#    Unnamed: 0  visits  nvisits  ovisits  novisits  emergency  hospital  \
# 0           1       5        0        0         0          0         1
# 1           2       1        0        2         0          2         0
# 2           3      13        0        0         0          3         3
# 3           4      16        0        5         0          1         1
# 4           5       3        0        0         0          0         0
#
#     health  chronic      adl region  age  gender married  school  income  \
# 0  average        2   normal  other  6.9    male     yes       6  2.8810
# 1  average        2   normal  other  7.4  female     yes      10  2.7478
# 2     poor        4  limited  other  6.6  female      no      10  0.6532
# 3     poor        2  limited  other  7.6    male     yes       3  0.6588
# 4  average        2  limited  other  7.9  female     yes       6  0.6588
#
#   employed insurance medicaid
# 0      yes       yes       no
# 1       no       yes       no
# ...

# %% [markdown]
# # Task
# Analyze the distributions of categorical columns in the dataframe `df`.

# %% [markdown]
# ## Identify categorical columns
#
# ### Subtask:
# Get the names of all columns with 'object' dtype.

# %% [markdown]
# **Reasoning**:
# Select columns with the 'object' data type from the DataFrame `df` and store their names in a list named `categorical_cols`.

# %%
categorical_cols = df.select_dtypes(include='object').columns.tolist()
display(categorical_cols)
# Out:
# ['health',
#  'adl',
#  'region',
#  'gender',
#  'married',
#  'employed',
#  'insurance',
#  'medicaid']

# %% [markdown]
# ## Visualize distributions
#
# ### Subtask:
# For each categorical column, generate a count plot or a bar chart to visualize the distribution of its unique values.

# %% [markdown]
# **Reasoning**:
# Iterate through the identified categorical columns and generate count plots for each to visualize their distributions.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

for col in categorical_cols:
    plt.figure(figsize=(8, 6))
    sns.countplot(data=df, x=col)
    plt.title(f'Distribution of {col}')
    plt.show()

# %% [markdown]
# ## Summary:
#
# ### Data Analysis Key Findings
#
# *   The analysis identified the following columns as categorical (with 'object' dtype): 'health', 'adl', 'region', 'gender', 'married', 'employed', 'insurance', and 'medicaid'.
# *   Count plots were successfully generated for each of these categorical columns, visualizing the distribution of unique values within each column.
#
# ### Insights or Next Steps
#
# *   Review the generated plots to understand the value distribution and potential imbalances within each categorical variable, which might inform further data cleaning or modeling steps.
# *   Consider whether certain categories need to be combined or if there are infrequent categories that could impact model performance.

# %% [markdown]
# # Task
# Investigate negative income values in the dataframe.

# %% [markdown]
# ## Identify negative income values
#
# ### Subtask:
# Filter the DataFrame to select rows where the 'income' column has negative values.

# %% [markdown]
# **Reasoning**:
# Filter the DataFrame to select rows where the 'income' column has negative values and display the resulting DataFrame.

# %%
negative_income_df = df[df['income'] < 0]
display(negative_income_df)
# Out:
#       Unnamed: 0  visits  nvisits  ovisits  novisits  emergency  hospital  \
# 909          910      10        0        0         0          0         0
# 910          911       9        2        0         0          0         0
# 2592        2593       6        0        0         0          0         0
#
#        health  chronic     adl region  age  gender married  school  income  \
# 909      poor        1  normal  other  7.8    male     yes      12 -1.0125
# 910   average        1  normal  other  7.5  female     yes      14 -1.0125
# 2592  average        4  normal   west  6.9    male     yes       6 -0.8180
#
#      employed insurance medicaid
# 909        no        no       no
# 910        no        no       no
# 2592       no       yes       no

# %% [markdown]
# ## Examine characteristics
#
# ### Subtask:
# Display the selected rows to see if there are any common characteristics among them.

# %% [markdown]
# **Reasoning**:
# Display the negative_income_df to visually inspect the rows and look for common characteristics.

# %%
display(negative_income_df)
# Out:
#       Unnamed: 0  visits  nvisits  ovisits  novisits  emergency  hospital  \
# 909          910      10        0        0         0          0         0
# 910          911       9        2        0         0          0         0
# 2592        2593       6        0        0         0          0         0
#
#        health  chronic     adl region  age  gender married  school  income  \
# 909      poor        1  normal  other  7.8    male     yes      12 -1.0125
# 910   average        1  normal  other  7.5  female     yes      14 -1.0125
# 2592  average        4  normal   west  6.9    male     yes       6 -0.8180
#
#      employed insurance medicaid
# 909        no        no       no
# 910        no        no       no
# 2592       no       yes       no

# %% [markdown]
# ## Quantify negative income values
#
# ### Subtask:
# Calculate the number of rows with negative income and the range of these negative values.

# %% [markdown]
# **Reasoning**:
# Calculate and print the number of rows and the range of negative income values in the `negative_income_df` DataFrame.

# %%
num_negative_income_rows = negative_income_df.shape[0]
min_negative_income = negative_income_df['income'].min()
max_negative_income = negative_income_df['income'].max()

print(f"Number of rows with negative income: {num_negative_income_rows}")
print(f"Range of negative income values: [{min_negative_income}, {max_negative_income}]")
# Out:
# Number of rows with negative income: 3
# Range of negative income values: [-1.0125, -0.818]

# %% [markdown]
# ## Summary:
#
# ### Data Analysis Key Findings
#
# * There are 3 rows in the dataset with negative income values.
# * The range of negative income values is between -1.0125 and -0.818.
#
# ### Insights or Next Steps
#
# * Investigate the source of these negative income values to understand if they represent errors, specific accounting practices, or other data anomalies.
# * Determine a strategy for handling these negative values, such as correction, exclusion, or further investigation based on their origin and impact on the analysis.

# %% [markdown]
# # Task
# Analyze the memory usage of the dataframe, recommend non-default data types to optimize memory settings, and optionally implement the recommended changes and verify the memory usage after optimization.

# %% [markdown]
# ## Check current memory usage
#
# ### Subtask:
# Display the memory usage of the DataFrame.

# %% [markdown]
# **Reasoning**:
# Display the memory usage of the DataFrame including deep memory usage for objects.

# %%
display(df.info(memory_usage='deep'))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4406 entries, 0 to 4405
# Data columns (total 19 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  4406 non-null   int64
#  1   visits      4406 non-null   int64
#  2   nvisits     4406 non-null   int64
#  3   ovisits     4406 non-null   int64
#  4   novisits    4406 non-null   int64
#  5   emergency   4406 non-null   int64
#  6   hospital    4406 non-null   int64
#  7   health      4406 non-null   object
#  8   chronic     4406 non-null   int64
#  9   adl         4406 non-null   object
#  10  region      4406 non-null   object
#  11  age         4406 non-null   float64
#  12  gender      4406 non-null   object
#  13  married     4406 non-null   object
#  14  school      4406 non-null   int64
#  15  income      4406 non-null   float64
#  16  employed    4406 non-null   object
#  17  insurance   4406 non-null   object
#  18  medicaid    4406 non-null   object
# ...

# %% [markdown]
# ## Analyze data types
#
# ### Subtask:
# Identify columns that can potentially use more memory-efficient data types.

# %% [markdown]
# **Reasoning**:
# Identify columns that can potentially use more memory-efficient data types by examining the output of `df.info(memory_usage='deep')` and the unique values of object type columns.

# %%
# Categorical columns identified in previous steps
categorical_cols = ['health', 'adl', 'region', 'gender', 'married', 'employed', 'insurance', 'medicaid']

# Examine unique values for categorical columns to confirm they are suitable for 'category' dtype
for col in categorical_cols:
    print(f"Unique values in '{col}':")
    display(df[col].unique())

# Examine numerical column ranges from df.describe() to consider smaller dtypes
display(df.describe())
# Out:
# Unique values in 'health':
# array(['average', 'poor', 'excellent'], dtype=object)
# Unique values in 'adl':
# array(['normal', 'limited'], dtype=object)
# Unique values in 'region':
# array(['other', 'midwest', 'northeast', 'west'], dtype=object)
# Unique values in 'gender':
# array(['male', 'female'], dtype=object)
# Unique values in 'married':
# array(['yes', 'no'], dtype=object)
# Unique values in 'employed':
# array(['yes', 'no'], dtype=object)
# Unique values in 'insurance':
# array(['yes', 'no'], dtype=object)
# Unique values in 'medicaid':
# array(['no', 'yes'], dtype=object)
#         Unnamed: 0       visits      nvisits      ovisits     novisits  \
# count  4406.000000  4406.000000  4406.000000  4406.000000  4406.000000
# mean   2203.500000     5.774399     1.618021     0.750794     0.536087
# std    1272.046972     6.759225     5.317056     3.652759     3.879506
# min       1.000000     0.000000     0.000000     0.000000     0.000000
# ...

# %% [markdown]
# ## Recommend data type optimizations
#
# ### Subtask:
# Suggest specific data type changes for columns to reduce memory usage.

# %% [markdown]
# **Reasoning**:
# Suggest data type changes for columns based on their current types, unique values, and ranges to optimize memory usage.

# %%
print("Recommended data type changes for memory optimization:")

# Recommendations for categorical columns
categorical_cols = ['health', 'adl', 'region', 'gender', 'married', 'employed', 'insurance', 'medicaid']
print("\nCategorical columns (currently object type):")
for col in categorical_cols:
    print(f"- '{col}': Convert to 'category' dtype. Reasoning: Limited number of unique values.")

# Recommendations for numerical columns based on df.describe() output from the previous step
print("\nNumerical columns:")

# Examine numerical column ranges from df.describe()
# The describe output shows max values for int columns and min/max for float.
# Based on the previous output:
# visits: max 89 -> int8
# nvisits: max 104 -> int16
# ovisits: max 141 -> int16
# novisits: max 155 -> int16
# emergency: max 12 -> int8
# hospital: max 8 -> int8
# chronic: max 8 -> int8
# age: range 6.6 to 10.9 -> float32
# school: max 18 -> int8
# income: range -1.0125 to 54.8351 -> float32

print("- 'visits': Convert to 'int8'. Reasoning: Max value is 89, which fits in int8.")
print("- 'nvisits': Convert to 'int16'. Reasoning: Max value is 104, which fits in int16.")
print("- 'ovisits': Convert to 'int16'. Reasoning: Max value is 141, which fits in int16.")
print("- 'novisits': Convert to 'int16'. Reasoning: Max value is 155, which fits in int16.")
print("- 'emergency': Convert to 'int8'. Reasoning: Max value is 12, which fits in int8.")
print("- 'hospital': Convert to 'int8'. Reasoning: Max value is 8, which fits in int8.")
print("- 'chronic': Convert to 'int8'. Reasoning: Max value is 8, which fits in int8.")
print("- 'age': Convert to 'float32'. Reasoning: The range fits within float32 precision.")
print("- 'school': Convert to 'int8'. Reasoning: Max value is 18, which fits in int8.")
print("- 'income': Convert to 'float32'. Reasoning: The range and precision are suitable for float32.")
print("- 'Unnamed: 0': Could potentially be dropped or kept as int64 if used as an identifier. Optimization to int32 is possible but might not be significant.")
# Out:
# Recommended data type changes for memory optimization:
#
# Categorical columns (currently object type):
# - 'health': Convert to 'category' dtype. Reasoning: Limited number of unique values.
# - 'adl': Convert to 'category' dtype. Reasoning: Limited number of unique values.
# - 'region': Convert to 'category' dtype. Reasoning: Limited number of unique values.
# - 'gender': Convert to 'category' dtype. Reasoning: Limited number of unique values.
# - 'married': Convert to 'category' dtype. Reasoning: Limited number of unique values.
# - 'employed': Convert to 'category' dtype. Reasoning: Limited number of unique values.
# - 'insurance': Convert to 'category' dtype. Reasoning: Limited number of unique values.
# - 'medicaid': Convert to 'category' dtype. Reasoning: Limited number of unique values.
#
# Numerical columns:
# - 'visits': Convert to 'int8'. Reasoning: Max value is 89, which fits in int8.
# - 'nvisits': Convert to 'int16'. Reasoning: Max value is 104, which fits in int16.
# ...

# %% [markdown]
# ## Implement data type optimizations (optional)
#
# ### Subtask:
# Generate code to change the data types of selected columns.

# %% [markdown]
# **Reasoning**:
# Create a dictionary of column to dtype mapping and use it to convert the dtypes of the specified columns.

# %%
dtype_mapping = {
    'health': 'category',
    'adl': 'category',
    'region': 'category',
    'gender': 'category',
    'married': 'category',
    'employed': 'category',
    'insurance': 'category',
    'medicaid': 'category',
    'visits': 'int8',
    'emergency': 'int8',
    'hospital': 'int8',
    'chronic': 'int8',
    'school': 'int8',
    'nvisits': 'int16',
    'ovisits': 'int16',
    'novisits': 'int16',
    'age': 'float32',
    'income': 'float32'
}

df = df.astype(dtype_mapping)

# %% [markdown]
# ## Verify memory usage after optimization (optional)
#
# ### Subtask:
# Display the memory usage of the DataFrame after applying the optimizations.

# %% [markdown]
# **Reasoning**:
# Display the memory usage of the DataFrame after applying the data type optimizations to verify the reduction in memory usage.

# %%
display(df.info(memory_usage='deep'))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4406 entries, 0 to 4405
# Data columns (total 19 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  4406 non-null   int64
#  1   visits      4406 non-null   int8
#  2   nvisits     4406 non-null   int16
#  3   ovisits     4406 non-null   int16
#  4   novisits    4406 non-null   int16
#  5   emergency   4406 non-null   int8
#  6   hospital    4406 non-null   int8
#  7   health      4406 non-null   category
#  8   chronic     4406 non-null   int8
#  9   adl         4406 non-null   category
#  10  region      4406 non-null   category
#  11  age         4406 non-null   float32
#  12  gender      4406 non-null   category
#  13  married     4406 non-null   category
#  14  school      4406 non-null   int8
#  15  income      4406 non-null   float32
#  16  employed    4406 non-null   category
#  17  insurance   4406 non-null   category
#  18  medicaid    4406 non-null   category
# ...

# %% [markdown]
# ## Summary:
#
# ### Data Analysis Key Findings
#
# *   The initial memory usage of the DataFrame was approximately 2.2 MB.
# *   Columns 'health', 'adl', 'region', 'gender', 'married', 'employed', 'insurance', and 'medicaid' were identified as `object` type and suitable for conversion to the `category` data type.
# *   Numerical columns like 'visits', 'emergency', 'hospital', 'chronic', and 'school' were suitable for conversion to `int8`.
# *   Numerical columns like 'nvisits', 'ovisits', and 'novisits' were suitable for conversion to `int16`.
# *   Numerical columns 'age' and 'income' were suitable for conversion to `float32`.
# *   After applying the recommended data type optimizations, the memory usage of the DataFrame was reduced to approximately 152.6 KB.
#
# ### Insights or Next Steps
#
# *   Optimizing data types significantly reduced the memory footprint of the DataFrame, from approximately 2.2 MB to 152.6 KB, which can improve performance and resource utilization.
# *   Consider automating this optimization process for future data loading by applying the recommended data types during the initial data loading step.
