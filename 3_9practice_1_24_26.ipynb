# %% [markdown]
# <a href="https://colab.research.google.com/github/angiecombs11-ops/PurdueHW/blob/main/3_9practice_1_24_26.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, cross_val_score, RepeatedKFold
from sklearn.linear_model import Ridge, RidgeCV
from sklearn.metrics import mean_squared_error, r2_score

df = pd.read_csv('Hitters.csv')
# Create and fit the Ridge regression model to the training data
ridge_model = Ridge(alpha=1).fit(X_train, y_train)
ridge_model.intercept_
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-809844173.py in <cell line: 0>()
#       7 df = pd.read_csv('Hitters.csv')
#       8 # Create and fit the Ridge regression model to the training data
# ----> 9 ridge_model = Ridge(alpha=1).fit(X_train, y_train)
#      10 ridge_model.intercept_
#
# NameError: name 'X_train' is not defined

# %% [markdown]
# ### Data Preparation for Ridge Regression

# %%
# Drop rows with missing 'Salary' values
df_clean = df.dropna(subset=['Salary'])

# Drop the 'Unnamed: 0' column if it exists and is an index artifact
if 'Unnamed: 0' in df_clean.columns:
    df_clean = df_clean.drop(columns=['Unnamed: 0'])

# Convert categorical variables into dummy/indicator variables
X = pd.get_dummies(df_clean.drop('Salary', axis=1), drop_first=True)
y = df_clean['Salary']

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

print(f"Shape of X_train: {X_train.shape}")
print(f"Shape of y_train: {y_train.shape}")
print(f"Shape of X_test: {X_test.shape}")
print(f"Shape of y_test: {y_test.shape}")
# Out:
# Shape of X_train: (184, 19)
# Shape of y_train: (184,)
# Shape of X_test: (79, 19)
# Shape of y_test: (79,)

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, cross_val_score, RepeatedKFold
from sklearn.linear_model import Ridge, RidgeCV
from sklearn.metrics import mean_squared_error, r2_score

df = pd.read_csv('Hitters.csv')
# Create and fit the Ridge regression model to the training data
ridge_model = Ridge(alpha=1).fit(X_train, y_train)
ridge_model.intercept_
# Out:
# np.float64(-19.166602397895304)
